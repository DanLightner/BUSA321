# %%
import seaborn as sns
import pandas as pd
df = pd.read_csv("pokemon.csv")
df
# Out:
#            name    type1   type2  weight_kg   hp  attack  defense  speed  \
# 0     Bulbasaur    grass  poison        6.9   45      49       49     45
# 1       Ivysaur    grass  poison       13.0   60      62       63     60
# 2      Venusaur    grass  poison      100.0   80     100      123     80
# 3    Charmander     fire     NaN        8.5   39      52       43     65
# 4    Charmeleon     fire     NaN       19.0   58      64       58     80
# ..          ...      ...     ...        ...  ...     ...      ...    ...
# 796  Celesteela    steel  flying      999.9   97     101      103     61
# 797     Kartana    grass   steel        0.1   59     181      131    109
# 798    Guzzlord     dark  dragon      888.0  223     101       53     43
# 799    Necrozma  psychic     NaN      230.0   97     107      101     79
# 800    Magearna    steel   fairy       80.5   80      95      115     65
#
#      generation  is_legendary
# 0             1             0
# ...

# %%
sns.jointplot(data=df, x='defense', y='attack')

# %%
sns.jointplot(data=df, x='weight_kg', y='defense')

# %%
sns.jointplot(data=df, x='attack', y='defense', kind="hex", color="k");

# %%
import matplotlib.pyplot as plt
sns.set_style('white')
f, ax = plt.subplots(figsize=(6, 6))
sns.kdeplot(x='attack', y='defense', data=df, ax=ax)
sns.rugplot(x='attack', data=df, color="g", ax=ax)
sns.rugplot(y='defense', data=df, ax=ax);

# %%
sns.set(rc={'axes.facecolor':'black', 'figure.facecolor':'white', 'axes.grid':False})
f, ax = plt.subplots(figsize=(6, 6))
cmap = sns.cubehelix_palette(as_cmap=True, dark=0.05, light=1, reverse=True)
sns.kdeplot(x='attack', y='defense', data=df, cmap=cmap, n_levels=60, shade=True);
# Out:
# C:\Users\danli\AppData\Local\Temp\ipykernel_15712\4271406969.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x='attack', y='defense', data=df, cmap=cmap, n_levels=60, shade=True);

# %%
sns.set_style('dark')
g = sns.jointplot(x="attack", y="defense", data=df, kind="kde", color="m")
g.plot_joint(plt.scatter, c="w", s=30, linewidth=1, marker="+")
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels("$X$", "$Y$");

# %%
df.dropna(inplace=True) # remove null values first
sns.pairplot(df);

# %%
g = sns.PairGrid(df)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, n_levels=60);

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv('insurance.csv')

# Pass in the DataFrame and the names of the x, y, and z variables (all must be numeric)
fig = px.scatter_3d(df, x='age', y='charges', z='bmi')
fig.show()

# %%
fig = px.scatter_3d(df, x='age', y='charges', z='bmi', color='smoker')
fig.show()
